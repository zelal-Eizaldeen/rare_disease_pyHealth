# %% [markdown]
# # Rare Disease Extraction

# %%
# Simple RDMA Pipeline Test for Jupyter Notebook

import numpy as np
import torch
from rdma.rd.extractor import RDMAExtractor
from rdma.rd.verifier import RDMAVerifier
from rdma.rd.matcher import RDMAMatcher
from rdma.utils.llm_client import LocalLLMClient
from rdma.utils.embedding import EmbeddingsManager

# Sample clinical texts
sample_texts = [
    "Patient presents with signs of Fabry disease including angiokeratomas and acroparesthesias. "
    "Family history is significant for renal failure in maternal uncle. "
    "No evidence of Gaucher disease. Labs show elevated globotriaosylceramide levels.",
    
    "43-year-old female with SLE and progressive dyspnea. Workup revealed PAH with RVSP of 68 mmHg. "
    "Diagnosis of CTD-PAH was made. Also noted was mild achalasia and Raynaud's phenomenon, "
    "raising suspicion for limited scleroderma (CREST syndrome)."
]

# Initialize LLM client
device = "cuda:0" if torch.cuda.is_available() else "cpu"
llm_client = LocalLLMClient(
    model_type="mistral_24b",  # Using a smaller model for faster testing
    device=device,
    temperature=0.1
)

# Initialize embedding manager
embeddings_file = "/u/zelalae2/scratch/data/vector_stores/rd_orpha_medembed.npy"
embedding_manager = EmbeddingsManager(
    model_type="sentence_transformer",
    model_name="abhinand/MedEmbed-small-v0.1",
    device=device
)

# Load embedded documents
embedded_documents = np.load(embeddings_file, allow_pickle=True)

# Initialize extractor
extractor = RDMAExtractor(
    llm_client=llm_client,
    extraction_method="retrieval",
    embedding_manager=embedding_manager,
    embedded_documents=embedded_documents,
    window_size=1,
    top_k=5,
    min_sentence_size=200,
    debug=True
)

# Extract entities from sample texts
extraction_results = {}
for i, text in enumerate(sample_texts):
    print(f"\nExtracting entities from text {i+1}:")
    entities_with_contexts = extractor.extract_from_text(text)
    print(f"Found {len(entities_with_contexts)} potential entities")
    
    # Display some extracted entities
    for j, entity in enumerate(entities_with_contexts[:2]):
        print(f"  Entity {j+1}: {entity.get('entity', '')}")
        
    # Store for next step
    extraction_results[f"text_{i+1}"] = {
        "clinical_text": text,
        "entities_with_contexts": entities_with_contexts,
    }

# Initialize verifier
verifier = RDMAVerifier(
    llm_client=llm_client,
    embedding_manager=embedding_manager,
    embedded_documents=embedded_documents,
    verifier_type="multi_stage",
    min_context_length=5,
    debug=True
)

# Verify entities
verification_results = verifier.verify_from_json(extraction_results)

# Display verification results
for text_id, result in verification_results.items():
    verified_entities = result.get("verified_rare_diseases", [])
    print(f"\n{text_id}: Verified {len(verified_entities)} entities as rare diseases")
    
    # Display some verified entities
    for j, entity in enumerate(verified_entities[:2]):
        print(f"  Verified entity {j+1}: {entity.get('entity', '')}")

# Initialize matcher
matcher = RDMAMatcher(
    llm_client=llm_client,
    embedding_manager=embedding_manager,
    embedded_documents=embedded_documents,
    top_k=5,
    debug=True
)

# Match entities to ORPHA codes
matching_results = matcher.match_from_json(verification_results)

# Display matching results
for text_id, result in matching_results.items():
    matched_entities = result.get("matched_diseases", [])
    print(f"\n{text_id}: Matched {len(matched_entities)} entities to ORPHA codes")
    
    # Display some matched entities
    for j, entity in enumerate(matched_entities[:2]):
        print(f"  Entity: {entity.get('entity', '')}")
        print(f"  Matched to: {entity.get('rd_term', '')} (ORPHA:{entity.get('orpha_id', '')})")
        print(f"  Method: {entity.get('match_method', '')}, Confidence: {entity.get('confidence_score', 0):.2f}")
# Out:
# /home/johnwu3/miniconda3/envs/hporag/lib/python3.10/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# Initialized ModelLoader with cache directory: /shared/rsaas/jw3/rare_disease/model_cache
# Loading LLM!
# Device configuration: cuda:0
# Using device map: {'': 'cuda:0'}
# Loading 70B model with quantization: mistral_24b
# Generated cache path: /shared/rsaas/jw3/rare_disease/model_cache/Mistral-Small-24B-Instruct-2501_4bit_nf4
# Valid cache found at /shared/rsaas/jw3/rare_disease/model_cache/Mistral-Small-24B-Instruct-2501_4bit_nf4
# Loading cached quantized model from /shared/rsaas/jw3/rare_disease/model_cache/Mistral-Small-24B-Instruct-2501_4bit_nf4
# /home/johnwu3/miniconda3/envs/hporag/lib/python3.10/site-packages/transformers/quantizers/auto.py:206: UserWarning: You passed `quantization_config` or equivalent parameters to `from_pretrained` but the model you're loading already has a `quantization_config` attribute. The `quantization_config` from the model will be used.
#   warnings.warn(warning_msg)
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Device set to use cuda:0
# Hello! I'm here to help. How can I assist you today? If you have any medical questions or need information on a specific topic, feel free to ask. Please note that while I strive to provide accurate and helpful information, I am an AI and my knowledge cutoff is 2023, and I don't have real-time web browsing capabilities or personal experiences. For urgent medical concerns, always consult a healthcare professional.
#
# Here are a few examples of how I can assist you:
#
# * Explain medical terms or concepts
# * Provide information on diseases, symptoms, and treatments
# * Offer insights into medical procedures and tests
# * Discuss healthcare guidelines and best practices
# * Answer questions related to biomedical research and studies
#
# What would you like to know or discuss?
# Loading model...
# Model type: sentence_transformer
# Model name: abhinand/MedEmbed-small-v0.1
# Device: cuda:0
# Initializing SentenceTransformer with model: abhinand/MedEmbed-small-v0.1 on device: cuda:0
# Model successfully moved to cuda:0
# Verifying model by embedding sample text...
# Model initialized successfully. Embedding dimension: 384
# 13:59:19 | Initializing retrieval-enhanced entity extractor
#
# Extracting entities from text 1:
# After merging: Processing 1 chunks instead of 4 raw sentences
# 13:59:22 | Extracted 4 potential rare disease entities
# 13:59:22 | Extracting contexts for 4 entities
# 13:59:22 | Extracted 4 sentences from text
# 13:59:22 |   Entity: 'Fabry disease'
# 13:59:22 |     Context: 'Patient presents with signs of Fabry disease including angiokeratomas and acroparesthesias.'
# 13:59:22 |   Entity: 'angiokeratomas'
# 13:59:22 |     Context: 'Patient presents with signs of Fabry disease including angiokeratomas and acroparesthesias.'
# 13:59:22 |   Entity: 'acroparesthesias'
# 13:59:22 |     Context: 'Patient presents with signs of Fabry disease including angiokeratomas and acroparesthesias.'
# 13:59:22 |   Entity: 'renal failure'
# 13:59:22 |     Context: 'Family history is significant for renal failure in maternal uncle.'
# Found 4 potential entities
#   Entity 1: Fabry disease
#   Entity 2: angiokeratomas
#
# Extracting entities from text 2:
# After merging: Processing 1 chunks instead of 4 raw sentences
# 13:59:25 | Extracted 7 potential rare disease entities
# 13:59:25 | Extracting contexts for 7 entities
# 13:59:25 | Extracted 4 sentences from text
# 13:59:25 |   Entity: 'SLE'
# 13:59:25 |     Context: '43-year-old female with SLE and progressive dyspnea.'
# 13:59:25 |   Entity: 'PAH'
# 13:59:25 |     Context: 'Workup revealed PAH with RVSP of 68 mmHg.'
# 13:59:25 |   Entity: 'CTD-PAH'
# 13:59:25 |     Context: 'Diagnosis of CTD-PAH was made.'
# 13:59:25 |   Entity: 'achalasia'
# 13:59:25 |     Context: 'Also noted was mild achalasia and Raynaud's phenomenon, raising suspicion for limited scleroderma (CREST syndrome).'
# 13:59:25 |   Entity: 'Raynaud's phenomenon'
# 13:59:25 |     Context: 'Also noted was mild achalasia and Raynaud's phenomenon, raising suspicion for limited scleroderma (CREST syndrome).'
# 13:59:25 |   Entity: 'limited scleroderma'
# 13:59:25 |     Context: 'Also noted was mild achalasia and Raynaud's phenomenon, raising suspicion for limited scleroderma (CREST syndrome).'
# 13:59:25 |   Entity: 'CREST syndrome'
# 13:59:25 |     Context: 'Also noted was mild achalasia and Raynaud's phenomenon, raising suspicion for limited scleroderma (CREST syndrome).'
# Found 7 potential entities
#   Entity 1: SLE
#   Entity 2: PAH
# 13:59:25 | Initializing multi-stage rare disease verifier
# 13:59:25 | Preparing FAISS index for rare disease verification...
# 13:59:25 | Index prepared with 26750 embedded documents
# 13:59:25 | Processing case 1/2 (ID: text_1)
# 13:59:25 |   Processing 4 raw entities
# 13:59:25 | Verifying 4 entities after filtering
# 13:59:25 | Processing batch of 4 entities
# 13:59:25 | Found 4 unique entity-context pairs
# 13:59:25 | Processing entity: 'Fabry disease'
# 13:59:25 |   Verifying if 'Fabry disease' is a rare disease via multi-step process
# 13:59:25 |     Exact ORPHA match found: 'Fabry disease' matches 'fabry disease' (ORPHA:324)
# 13:59:26 |     Multi-step verification: 'Fabry disease' is a rare disease
# 13:59:26 |   'Fabry disease' is a rare disease
# 13:59:26 | Processing entity: 'angiokeratomas'
# 13:59:26 |   Verifying if 'angiokeratomas' is a rare disease via multi-step process
# 13:59:26 |     No close ORPHA match found via string or LLM matching for 'angiokeratomas'
# 13:59:26 |   'angiokeratomas' is not a rare disease
# 13:59:26 | Processing entity: 'acroparesthesias'
# 13:59:26 |   Verifying if 'acroparesthesias' is a rare disease via multi-step process
# 13:59:27 |     No close ORPHA match found via string or LLM matching for 'acroparesthesias'
# 13:59:27 |   'acroparesthesias' is not a rare disease
# 13:59:27 | Processing entity: 'renal failure'
# 13:59:27 |   Verifying if 'renal failure' is a rare disease via multi-step process
# 13:59:27 |     No close ORPHA match found via string or LLM matching for 'renal failure'
# 13:59:27 |   'renal failure' is not a rare disease
# 13:59:27 | Identified 1 verified rare diseases
# 13:59:27 | Processing case 2/2 (ID: text_2)
# 13:59:27 |   Processing 7 raw entities
# 13:59:27 | Verifying 7 entities after filtering
# 13:59:27 | Processing batch of 7 entities
# 13:59:27 | Found 7 unique entity-context pairs
# 13:59:27 | Processing entity: 'SLE'
# 13:59:27 |   Verifying if 'SLE' is a rare disease via multi-step process
# 13:59:27 |     Exact ORPHA match found: 'SLE' matches 'sle' (Orpha:536)
# 13:59:28 |     Multi-step verification: 'SLE' is a rare disease
# 13:59:28 |   'SLE' is a rare disease
# 13:59:28 | Processing entity: 'PAH'
# 13:59:28 |   Verifying if 'PAH' is a rare disease via multi-step process
# 13:59:28 |     Exact ORPHA match found: 'PAH' matches 'pah' (Orpha:182090)
# 13:59:28 |     Multi-step verification: 'PAH' is not a rare disease
# 13:59:28 |   'PAH' is not a rare disease
# 13:59:28 | Processing entity: 'CTD-PAH'
# 13:59:28 |   Verifying if 'CTD-PAH' is a rare disease via multi-step process
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# 13:59:29 |     No close ORPHA match found via string or LLM matching for 'CTD-PAH'
# 13:59:29 |   'CTD-PAH' is not a rare disease
# 13:59:29 | Processing entity: 'achalasia'
# 13:59:29 |   Verifying if 'achalasia' is a rare disease via multi-step process
# 13:59:29 |     LLM identified semantic match: 'achalasia' matches 'achalasia cardia' (Orpha:930)
# 13:59:30 |     Multi-step verification: 'achalasia' is a rare disease
# 13:59:30 |   'achalasia' is a rare disease
# 13:59:30 | Processing entity: 'Raynaud's phenomenon'
# 13:59:30 |   Verifying if 'Raynaud's phenomenon' is a rare disease via multi-step process
# 13:59:30 |     No close ORPHA match found via string or LLM matching for 'Raynaud's phenomenon'
# 13:59:30 |   'Raynaud's phenomenon' is not a rare disease
# 13:59:30 | Processing entity: 'limited scleroderma'
# 13:59:30 |   Verifying if 'limited scleroderma' is a rare disease via multi-step process
# 13:59:31 |     No close ORPHA match found via string or LLM matching for 'limited scleroderma'
# 13:59:31 |   'limited scleroderma' is not a rare disease
# 13:59:31 | Processing entity: 'CREST syndrome'
# 13:59:31 |   Verifying if 'CREST syndrome' is a rare disease via multi-step process
# 13:59:31 |     Exact ORPHA match found: 'CREST syndrome' matches 'crest syndrome' (ORPHA:90290)
# 13:59:31 |     Multi-step verification: 'CREST syndrome' is a rare disease
# 13:59:31 |   'CREST syndrome' is a rare disease
# 13:59:31 | Identified 3 verified rare diseases
#
# text_1: Verified 1 entities as rare diseases
#   Verified entity 1: fabry disease
#
# text_2: Verified 3 entities as rare diseases
#   Verified entity 1: sle
#   Verified entity 2: achalasia cardia
# 13:59:31 | Initializing rare disease matcher
# 13:59:31 | Preparing matcher index
# 13:59:31 | Processing case 1/2 (ID: text_1)
# 13:59:31 |   Found 1 verified rare diseases
# 13:59:31 | Matching 1 verified entities to ORPHA codes
# {'entity': 'fabry disease', 'original_entity': 'Fabry disease', 'top_candidates': [{'name': 'fabry disease', 'id': 'ORPHA:324', 'similarity': 0.7735935264468795}, {'name': 'fabry disease', 'id': 'Orpha:324', 'similarity': 0.7735935264468795}, {'name': 'anderson-fabry disease', 'id': 'Orpha:324', 'similarity': 0.7495596499860182}, {'name': 'fryns-hofkens-fabry syndrome', 'id': 'Orpha:2497', 'similarity': 0.6690233381940615}, {'name': 'fd', 'id': 'Orpha:324', 'similarity': 0.660321464610913}]}
# 13:59:31 | Processing case 2/2 (ID: text_2)
# 13:59:31 |   Found 3 verified rare diseases
# 13:59:31 | Matching 3 verified entities to ORPHA codes
# {'entity': 'sle', 'original_entity': 'SLE', 'top_candidates': [{'name': 'sle', 'id': 'Orpha:536', 'similarity': 0.7906186903914252}, {'name': 'sle, pediatric onset', 'id': 'Orpha:93552', 'similarity': 0.6917352493593687}, {'name': 'idiopathic non-lupus full-house nephropathy', 'id': 'ORPHA:567544', 'similarity': 0.6632575317918326}, {'name': 'idiopathic non-lupus full-house nephropathy', 'id': 'Orpha:567544', 'similarity': 0.6632575317918326}, {'name': 'idiopathic non-lupus fhn', 'id': 'Orpha:567544', 'similarity': 0.6477781614812134}]}
# {'entity': 'achalasia cardia', 'original_entity': 'achalasia', 'top_candidates': [{'name': 'achalasia cardia', 'id': 'Orpha:930', 'similarity': 0.7660552884165366}, {'name': 'achalasia-alacrimia syndrome', 'id': 'ORPHA:99777', 'similarity': 0.6679865771344453}, {'name': 'primary achalasia', 'id': 'Orpha:930', 'similarity': 0.6625086233210932}, {'name': 'idiopathic achalasia', 'id': 'ORPHA:930', 'similarity': 0.656471719470868}, {'name': 'idiopathic achalasia', 'id': 'Orpha:930', 'similarity': 0.656471719470868}]}
# {'entity': 'crest syndrome', 'original_entity': 'CREST syndrome', 'top_candidates': [{'name': 'crest syndrome', 'id': 'ORPHA:90290', 'similarity': 0.9999999999996685}, {'name': 'deafness-skeletal dysplasia-coarse face with full lips syndrome', 'id': 'Orpha:3219', 'similarity': 0.6547403496409726}, {'name': 'deafness-skeletal dysplasia-lip granuloma syndrome', 'id': 'Orpha:3219', 'similarity': 0.6521624678004515}, {'name': 'waardenburg syndrome', 'id': 'ORPHA:3440', 'similarity': 0.6468992152712674}, {'name': 'waardenburg syndrome', 'id': 'Orpha:3440', 'similarity': 0.6460582252816115}]}
#
# text_1: Matched 1 entities to ORPHA codes
#   Entity: fabry disease
#   Matched to: fabry disease (ORPHA:ORPHA:324)
#   Method: exact, Confidence: 1.00
#
# text_2: Matched 3 entities to ORPHA codes
#   Entity: sle
#   Matched to: sle (ORPHA:Orpha:536)
#   Method: exact, Confidence: 1.00
#   Entity: achalasia cardia
#   Matched to: achalasia cardia (ORPHA:Orpha:930)
#   Method: exact, Confidence: 1.00

# %% [markdown]
# # Phenotype Extraction

# %%
#!/usr/bin/env python
# coding: utf-8

import torch
from typing import List, Dict, Any
from pprint import pprint

# Import the HPO pipeline modules
from rdma.hpo.extractor import PhenotypeExtractor
from rdma.hpo.verifier import HPOVerifier
from rdma.hpo.matcher import HPOMatcher
from rdma.utils.llm_client import LocalLLMClient

def run_hpo_pipeline(clinical_texts: List[str]):
    """
    Run the complete HPO pipeline on a list of clinical texts.
    
    Args:
        clinical_texts: List of clinical text strings to process
        
    Returns:
        Tuple of (extracted_entities, verified_phenotypes, matched_phenotypes)
    """
    # Configuration parameters
    model_type = "mistral_24b"
    temperature = 0.001
    cache_dir = "/u/zelalae2/scratch/rdma_cache"
    entity_extractor_type = "retrieval"
    embeddings_file = "/u/zelalae2/scratch/data/vector_stores/G2GHPO_metadata_medembed.npy"
    lab_embeddings_file = "/u/zelalae2/scratch/data/vector_stores/lab_tables_medembed_sm.npy"
    retriever = "sentence_transformer"
    retriever_model = "abhinand/MedEmbed-small-v0.1"
    verifier_version = "v4"
    top_k = 5
    debug = True

    # Initialize LLM client
    print("Initializing LLM client...")
    device = "cuda" if torch.cuda.is_available() else "cpu"
    print(f"Using device: {device}")
    
    llm_client = LocalLLMClient(
        model_type=model_type,
        device=device,
        cache_dir=cache_dir,
        temperature=temperature
    )
    
    # Initialize pipeline components
    print("\nInitializing pipeline components...")
    extractor = PhenotypeExtractor(
        llm_client=llm_client,
        extractor_type=entity_extractor_type,
        retriever=retriever,
        retriever_model=retriever_model,
        embeddings_file=embeddings_file,
        top_k=top_k,
        debug=debug
    )
    
    verifier = HPOVerifier(
        verifier_version=verifier_version,
        embeddings_file=embeddings_file,
        lab_embeddings_file=lab_embeddings_file,
        retriever=retriever,
        retriever_model=retriever_model,
        llm_client=llm_client,
        debug=debug,
        use_demographics=True
    )
    
    matcher = HPOMatcher(
        llm_client=llm_client,
        embeddings_file=embeddings_file,
        retriever=retriever,
        retriever_model=retriever_model,
        top_k=top_k,
        debug=debug
    )
    
    # Process all clinical texts
    all_extracted_entities = []
    all_verified_phenotypes = []
    all_matched_phenotypes = []
    
    for i, clinical_text in enumerate(clinical_texts):
        print(f"\n\n{'='*80}")
        print(f"Processing Clinical Text #{i+1}")
        print(f"{'='*80}")
        
        # Step 1: Extract phenotype entities
        print("\nStep 1: Extracting entities...")
        entities_with_contexts = extractor.extract([clinical_text])
        print(f"Extracted {len(entities_with_contexts)} entities with contexts.")
        
        for entity in entities_with_contexts:
            print(f"Entity: {entity.get('entity')}")
            print(f"Context: {entity.get('context')}")
            print("---")
        
        # Step 2: Verify entities as phenotypes
        print("\nStep 2: Verifying phenotypes...")
        verified_phenotypes = verifier.verify(entities_with_contexts, clinical_text)
        print(f"Verified {len(verified_phenotypes)} phenotypes.")
        
        for phenotype in verified_phenotypes:
            print(f"Phenotype: {phenotype.get('phenotype', phenotype.get('entity', ''))}")
            print(f"Status: {phenotype.get('status', 'unknown')}")
            if 'lab_info' in phenotype:
                lab_info = phenotype.get('lab_info', {})
                print(f"Lab: {lab_info.get('lab_name')} = {lab_info.get('value')} ({lab_info.get('direction')})")
            print("---")
        
        # Step 3: Match verified phenotypes to HPO codes
        print("\nStep 3: Matching phenotypes to HPO codes...")
        matched_phenotypes = matcher.match(verified_phenotypes)
        print(f"Matched {len(matched_phenotypes)} phenotypes to HPO codes.")
        
        for match in matched_phenotypes:
            print(f"Entity: {match.get('phenotype', '')}")
            print(f"Context: {match.get('context', '')}")
            print(f"Type: {match.get('status', '')}")
            print(f"Code: {match.get('hp_id', '')}")
            print("---")
        
        # Collect results for each text
        all_extracted_entities.extend(entities_with_contexts)
        all_verified_phenotypes.extend(verified_phenotypes)
        all_matched_phenotypes.extend(matched_phenotypes)
    
    # Print summary
    print("\n\n" + "="*80)
    print("PIPELINE SUMMARY")
    print("="*80)
    print(f"Total extracted entities: {len(all_extracted_entities)}")
    print(f"Total verified phenotypes: {len(all_verified_phenotypes)}")
    print(f"Total matched HPO codes: {len(all_matched_phenotypes)}")
    
    # Count direct vs. implied phenotypes
    direct_count = sum(1 for p in all_verified_phenotypes if p.get('status') == 'direct_phenotype')
    implied_count = sum(1 for p in all_verified_phenotypes if p.get('status') == 'implied_phenotype')
    print(f"Direct phenotypes: {direct_count}")
    print(f"Implied phenotypes: {implied_count}")
    
    return all_extracted_entities, all_verified_phenotypes, all_matched_phenotypes


if __name__ == "__main__":
    # Example clinical texts to process
    clinical_texts = [
        """
        Patient is a 5-year-old male with history of developmental delay and seizures. 
        Physical examination reveals macrocephaly, with head circumference in the 98th percentile.
        He has hypotonia and hyperreflexia. EEG showed abnormal spike-wave discharges.
        Genetic testing reveals a pathogenic variant in MECP2. 
        Lab results show elevated ammonia at 150 μmol/L (normal range 10-35).
        """,
        
        """
        42-year-old female with progressive vision loss. Fundoscopic examination shows 
        bilateral retinitis pigmentosa. Patient reports night blindness since adolescence.
        Family history is significant for similar symptoms in mother and maternal uncle.
        Physical exam also reveals polydactyly of both hands with six digits on each hand.
        Renal function is abnormal with elevated creatinine of 2.1 mg/dL.
        """
    ]
    
    # Run the HPO pipeline
    extracted, verified, matched = run_hpo_pipeline(clinical_texts)
# Out:
# Initializing LLM client...
# Using device: cuda
# Initialized ModelLoader with cache directory: /shared/rsaas/jw3/rare_disease/model_cache
# Loading LLM!
# Device configuration: cuda
# Using device map: {'': 'cuda'}
# Loading 70B model with quantization: mistral_24b
# Generated cache path: /shared/rsaas/jw3/rare_disease/model_cache/Mistral-Small-24B-Instruct-2501_4bit_nf4
# Valid cache found at /shared/rsaas/jw3/rare_disease/model_cache/Mistral-Small-24B-Instruct-2501_4bit_nf4
# Loading cached quantized model from /shared/rsaas/jw3/rare_disease/model_cache/Mistral-Small-24B-Instruct-2501_4bit_nf4
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Device set to use cuda
# Hello! I'm here to help. How can I assist you today? If you have any medical questions or need information on a specific topic, feel free to ask. Please note that while I strive to provide accurate and helpful information, I am an AI and my knowledge cutoff is 2023, so I might not have real-time or up-to-date information. For urgent medical concerns, always consult a healthcare professional.
#
# Here are a few examples of how I can assist you:
#
# * Explain medical terms or concepts
# * Provide information on diseases, symptoms, and treatments
# * Offer insights into medical procedures and tests
# * Discuss healthcare guidelines and best practices
# * Answer questions related to biomedical research and studies
#
# What would you like to know or discuss?
#
# Initializing pipeline components...
# Using device for retriever: cuda
# Using default system prompt
# Initializing retrieval entity extractor
# Loading model...
# Model type: sentence_transformer
# Model name: abhinand/MedEmbed-small-v0.1
# Device: cuda
# Initializing SentenceTransformer with model: abhinand/MedEmbed-small-v0.1 on device: cuda
# Model successfully moved to cuda
# Verifying model by embedding sample text...
# Model initialized successfully. Embedding dimension: 384
# Loaded 61401 embedded documents
# Using device: cuda
# Initialized demographics extractor for lab test analysis
# Initializing sentence_transformer embedding manager
# Loading model...
# Model type: sentence_transformer
# Model name: abhinand/MedEmbed-small-v0.1
# Device: cuda
# Initializing SentenceTransformer with model: abhinand/MedEmbed-small-v0.1 on device: cuda
# Model successfully moved to cuda
# Verifying model by embedding sample text...
# Model initialized successfully. Embedding dimension: 384
# Using default optimized configuration
# Loading embeddings from data/vector_stores/G2GHPO_metadata_medembed.npy
# Loaded 61401 embedded documents
# Initializing V4 verifier
# 16:42:08 | Initializing lab test searcher with data/tools/lab_tables_medembed_sm.npy
# Loading model...
# Model type: sentence_transformer
# Model name: abhinand/MedEmbed-small-v0.1
# Device: cpu
# Initializing SentenceTransformer with model: abhinand/MedEmbed-small-v0.1 on device: cpu
# Model running on CPU
# Verifying model by embedding sample text...
# Model initialized successfully. Embedding dimension: 384
# Loading embeddings from data/tools/lab_tables_medembed_sm.npy
# Loaded 105 embedded documents
# Created FAISS index with 105 vectors of dimension 384
# 16:42:08 | Lab test searcher initialized successfully
# 16:42:08 | Preparing FAISS index for phenotype verification...
# 16:42:09 | Index prepared with 61401 embedded documents
# Using device: cuda
# Using default system prompt
# Initializing sentence_transformer embedding manager
# Loading model...
# Model type: sentence_transformer
# Model name: abhinand/MedEmbed-small-v0.1
# Device: cuda
# Initializing SentenceTransformer with model: abhinand/MedEmbed-small-v0.1 on device: cuda
# Model successfully moved to cuda
# Verifying model by embedding sample text...
# Model initialized successfully. Embedding dimension: 384
# Loading embeddings from data/vector_stores/G2GHPO_metadata_medembed.npy
# Loaded 61401 embedded documents
# Initializing standard matcher
#
#
# ================================================================================
# Processing Clinical Text #1
# ================================================================================
#
# Step 1: Extracting entities...
# Extracting entities from 1 clinical texts
# Extracted 10 entities from text 0
# 16:42:24 | Extracting contexts for 10 entities
# 16:42:24 | Extracted 6 sentences from text
# 16:42:24 |   Entity: 'developmental delay'
# 16:42:24 |     Context: 'Patient is a 5-year-old male with history of developmental delay and seizures.'
# 16:42:24 |   Entity: 'seizures'
# 16:42:24 |     Context: 'Patient is a 5-year-old male with history of developmental delay and seizures.'
# 16:42:24 |   Entity: 'macrocephaly'
# 16:42:24 |     Context: 'Physical examination reveals macrocephaly, with head circumference in the 98th percentile.'
# 16:42:24 |   Entity: 'head circumference in the 98th percentile'
# 16:42:24 |     Context: 'Physical examination reveals macrocephaly, with head circumference in the 98th percentile.'
# 16:42:24 |   Entity: 'hypotonia'
# 16:42:24 |     Context: 'He has hypotonia and hyperreflexia.'
# 16:42:24 |   Entity: 'hyperreflexia'
# 16:42:24 |     Context: 'He has hypotonia and hyperreflexia.'
# 16:42:24 |   Entity: 'abnormal spike-wave discharges'
# 16:42:24 |     Context: 'EEG showed abnormal spike-wave discharges.'
# 16:42:24 |   Entity: 'pathogenic variant'
# 16:42:24 |     Context: 'Genetic testing reveals a pathogenic variant in MECP2.'
# 16:42:24 |   Entity: 'elevated ammonia'
# 16:42:24 |     Context: 'Lab results show elevated ammonia at 150 μmol/L (normal range 10-35).'
# 16:42:24 |   Entity: '150 μmol/L'
# 16:42:24 |     Context: 'Lab results show elevated ammonia at 150 μmol/L (normal range 10-35).'
# Total entities with contexts: 10
# Extracted 10 entities with contexts.
# Entity: developmental delay
# Context: Patient is a 5-year-old male with history of developmental delay and seizures.
# ---
# Entity: seizures
# Context: Patient is a 5-year-old male with history of developmental delay and seizures.
# ---
# Entity: macrocephaly
# Context: Physical examination reveals macrocephaly, with head circumference in the 98th percentile.
# ---
# Entity: head circumference in the 98th percentile
# Context: Physical examination reveals macrocephaly, with head circumference in the 98th percentile.
# ---
# Entity: hypotonia
# Context: He has hypotonia and hyperreflexia.
# ---
# Entity: hyperreflexia
# Context: He has hypotonia and hyperreflexia.
# ---
# Entity: abnormal spike-wave discharges
# Context: EEG showed abnormal spike-wave discharges.
# ---
# Entity: pathogenic variant
# Context: Genetic testing reveals a pathogenic variant in MECP2.
# ---
# Entity: elevated ammonia
# Context: Lab results show elevated ammonia at 150 μmol/L (normal range 10-35).
# ---
# Entity: 150 μmol/L
# Context: Lab results show elevated ammonia at 150 μmol/L (normal range 10-35).
# ---
#
# Step 2: Verifying phenotypes...
# Verifying 10 entities
# Processing 10 entities after filtering
# 16:42:24 |   Extracting demographics from clinical note
# 16:42:26 |     Extracted demographics: age=5, gender=male, age_group=child
# Extracted demographics: {'age': 5, 'gender': 'male', 'age_group': 'child'}
# 16:42:26 | Processing entity: 'developmental delay'
# 16:42:26 |   Verifying if 'developmental delay' is a direct phenotype via binary matching
# 16:42:26 |     Exact match found: 'developmental delay' matches 'developmental delay' (HP:0001263)
# 16:42:26 |   'developmental delay' is a direct phenotype
# 16:42:26 | Processing entity: 'seizures'
# 16:42:26 |   Verifying if 'seizures' is a direct phenotype via binary matching
# 16:42:26 |     Exact match found: 'seizures' matches 'seizures' (HP:0001250)
# 16:42:26 |   'seizures' is a direct phenotype
# 16:42:26 | Processing entity: 'macrocephaly'
# 16:42:26 |   Verifying if 'macrocephaly' is a direct phenotype via binary matching
# 16:42:26 |     Exact match found: 'macrocephaly' matches 'macrocephaly' (HP:0000256)
# 16:42:26 |   'macrocephaly' is a direct phenotype
# 16:42:26 | Processing entity: 'head circumference in the 98th percentile'
# 16:42:26 |   Verifying if 'head circumference in the 98th percentile' is a direct phenotype via binary matching
# 16:42:27 |     LLM binary verification: 'head circumference in the 98th percentile' is a phenotype
# 16:42:27 |   'head circumference in the 98th percentile' is a direct phenotype
# 16:42:27 | Processing entity: 'hypotonia'
# 16:42:27 |   Verifying if 'hypotonia' is a direct phenotype via binary matching
# 16:42:27 |     Exact match found: 'hypotonia' matches 'hypotonia' (HP:0001252)
# 16:42:27 |   'hypotonia' is a direct phenotype
# 16:42:27 | Processing entity: 'hyperreflexia'
# 16:42:27 |   Verifying if 'hyperreflexia' is a direct phenotype via binary matching
# 16:42:27 |     Exact match found: 'hyperreflexia' matches 'hyperreflexia' (HP:0001347)
# 16:42:27 |   'hyperreflexia' is a direct phenotype
# 16:42:27 | Processing entity: 'abnormal spike-wave discharges'
# 16:42:27 |   Verifying if 'abnormal spike-wave discharges' is a direct phenotype via binary matching
# 16:42:28 |     LLM binary verification: 'abnormal spike-wave discharges' is a phenotype
# 16:42:28 |   'abnormal spike-wave discharges' is a direct phenotype
# 16:42:28 | Processing entity: 'pathogenic variant'
# 16:42:28 |   Verifying if 'pathogenic variant' is a direct phenotype via binary matching
# 16:42:29 |     LLM binary verification: 'pathogenic variant' is not a phenotype
# 16:42:29 |   Detecting if 'pathogenic variant' is a lab test with measurement (numbers present)
# 16:42:29 |     LLM detection: 'pathogenic variant' is not a lab test with measurement
# 16:42:29 |   Checking if 'pathogenic variant' implies a phenotype
# 16:42:30 |     LLM binary verification: 'pathogenic variant' does not imply a phenotype
# 16:42:30 |   'pathogenic variant' is not a phenotype and doesn't imply one
# 16:42:30 | Processing entity: 'elevated ammonia'
# 16:42:30 |   Verifying if 'elevated ammonia' is a direct phenotype via binary matching
# 16:42:31 |     LLM binary verification: 'elevated ammonia' is a phenotype
# 16:42:31 |   'elevated ammonia' is a direct phenotype
# 16:42:31 | Processing entity: '150 μmol/L'
# 16:42:31 |   Verifying if '150 μmol/L' is a direct phenotype via binary matching
# 16:42:31 |     LLM binary verification: '150 μmol/L' is not a phenotype
# 16:42:31 |   Detecting if '150 μmol/L' is a lab test with measurement (numbers present)
# 16:42:32 |     LLM detection: '150 μmol/L' is a lab test with measurement
# 16:42:32 |   '150 μmol/L' is a lab test, performing analysis
# 16:42:32 |   Analyzing lab test '150 μmol/L' for extraction and abnormality
# 16:42:32 |     Searching for lab test reference ranges: '150'
# 16:42:32 |     Retrieved 5 reference range entries
# 16:42:36 |     Lab test analysis: '150 μmol/L' is abnormal: elevated ammonia (high)
# 16:42:36 |   Validating phenotype 'elevated ammonia' via binary matching
# 16:42:37 |     LLM binary validation: 'elevated ammonia' is a valid phenotype
# 16:42:37 |   Lab abnormality 'elevated ammonia' is a valid phenotype
# Identified 9 phenotypes (direct or implied)
# Verified 9 phenotypes.
# Phenotype: developmental delay
# Status: direct_phenotype
# ---
# Phenotype: seizures
# Status: direct_phenotype
# ---
# Phenotype: macrocephaly
# Status: direct_phenotype
# ---
# Phenotype: head circumference in the 98th percentile
# Status: direct_phenotype
# ---
# Phenotype: hypotonia
# Status: direct_phenotype
# ---
# Phenotype: hyperreflexia
# Status: direct_phenotype
# ---
# Phenotype: abnormal spike-wave discharges
# Status: direct_phenotype
# ---
# Phenotype: elevated ammonia
# Status: direct_phenotype
# ---
# Phenotype: elevated ammonia
# Status: implied_phenotype
# Lab: ammonia = 150 (high)
# ---
#
# Step 3: Matching phenotypes to HPO codes...
# Matching 9 phenotypes to HPO terms
# Successfully matched 9 phenotypes
# Matched 9 phenotypes to HPO codes.
# Entity: developmental delay
# Context: Patient is a 5-year-old male with history of developmental delay and seizures.
# Type: direct_phenotype
# Code: HP:0001263
# ---
# Entity: seizures
# Context: Patient is a 5-year-old male with history of developmental delay and seizures.
# Type: direct_phenotype
# Code: HP:0001250
# ---
# Entity: macrocephaly
# Context: Physical examination reveals macrocephaly, with head circumference in the 98th percentile.
# Type: direct_phenotype
# Code: HP:0000256
# ---
# Entity: head circumference in the 98th percentile
# Context: Physical examination reveals macrocephaly, with head circumference in the 98th percentile.
# Type: direct_phenotype
# Code: HP:0000256
# ---
# Entity: hypotonia
# Context: He has hypotonia and hyperreflexia.
# Type: direct_phenotype
# Code: HP:0001252
# ---
# Entity: hyperreflexia
# Context: He has hypotonia and hyperreflexia.
# Type: direct_phenotype
# Code: HP:0001347
# ---
# Entity: abnormal spike-wave discharges
# Context: EEG showed abnormal spike-wave discharges.
# Type: direct_phenotype
# Code: HP:0010847
# ---
# Entity: elevated ammonia
# Context: Lab results show elevated ammonia at 150 μmol/L (normal range 10-35).
# Type: direct_phenotype
# Code: HP:0001987
# ---
# Entity: elevated ammonia
# Context: Lab results show elevated ammonia at 150 μmol/L (normal range 10-35).
# Type: implied_phenotype
# Code: HP:0001987
# ---
#
#
# ================================================================================
# Processing Clinical Text #2
# ================================================================================
#
# Step 1: Extracting entities...
# Extracting entities from 1 clinical texts
# Extracted 9 entities from text 0
# 16:42:58 | Extracting contexts for 9 entities
# 16:42:58 | Extracted 8 sentences from text
# 16:42:58 |   Entity: 'vision loss'
# 16:42:58 |     Context: '42-year-old female with progressive vision loss.'
# 16:42:58 |   Entity: 'Fundoscopic examination'
# 16:42:58 |     Context: 'Fundoscopic examination shows'
# 16:42:58 |   Entity: 'bilateral retinitis pigmentosa'
# 16:42:58 |     Context: 'bilateral retinitis pigmentosa.'
# 16:42:58 |   Entity: 'night blindness'
# 16:42:58 |     Context: 'Patient reports night blindness since adolescence.'
# 16:42:58 |   Entity: 'similar symptoms'
# 16:42:58 |     Context: 'Family history is significant for similar symptoms in mother and maternal uncle.'
# 16:42:58 |   Entity: 'polydactyly of both hands'
# 16:42:58 |     Context: 'Physical exam also reveals polydactyly of both hands with six digits on each hand.'
# 16:42:58 |   Entity: 'six digits on each hand'
# 16:42:58 |     Context: 'Physical exam also reveals polydactyly of both hands with six digits on each hand.'
# 16:42:58 |   Entity: 'Renal function is abnormal'
# 16:42:58 |     Context: 'Renal function is abnormal with elevated creatinine of 2.'
# 16:42:58 |   Entity: 'elevated creatinine'
# 16:42:58 |     Context: 'Renal function is abnormal with elevated creatinine of 2.'
# Total entities with contexts: 9
# Extracted 9 entities with contexts.
# Entity: vision loss
# Context: 42-year-old female with progressive vision loss.
# ---
# Entity: Fundoscopic examination
# Context: Fundoscopic examination shows
# ---
# Entity: bilateral retinitis pigmentosa
# Context: bilateral retinitis pigmentosa.
# ---
# Entity: night blindness
# Context: Patient reports night blindness since adolescence.
# ---
# Entity: similar symptoms
# Context: Family history is significant for similar symptoms in mother and maternal uncle.
# ---
# Entity: polydactyly of both hands
# Context: Physical exam also reveals polydactyly of both hands with six digits on each hand.
# ---
# Entity: six digits on each hand
# Context: Physical exam also reveals polydactyly of both hands with six digits on each hand.
# ---
# Entity: Renal function is abnormal
# Context: Renal function is abnormal with elevated creatinine of 2.
# ---
# Entity: elevated creatinine
# Context: Renal function is abnormal with elevated creatinine of 2.
# ---
#
# Step 2: Verifying phenotypes...
# Verifying 9 entities
# Processing 9 entities after filtering
# 16:42:58 |   Extracting demographics from clinical note
# 16:43:00 |     Extracted demographics: age=42, gender=female, age_group=adult
# Extracted demographics: {'age': 42, 'gender': 'female', 'age_group': 'adult'}
# 16:43:00 | Processing entity: 'vision loss'
# 16:43:00 |   Verifying if 'vision loss' is a direct phenotype via binary matching
# 16:43:00 |     Exact match found: 'vision loss' matches 'vision loss' (HP:0000572)
# 16:43:00 |   'vision loss' is a direct phenotype
# 16:43:00 | Processing entity: 'Fundoscopic examination'
# 16:43:00 |   Verifying if 'Fundoscopic examination' is a direct phenotype via binary matching
# 16:43:01 |     LLM binary verification: 'Fundoscopic examination' is not a phenotype
# 16:43:01 |   Checking if 'Fundoscopic examination' implies a phenotype
# 16:43:02 |     LLM binary verification: 'Fundoscopic examination' does not imply a phenotype
# 16:43:02 |   'Fundoscopic examination' is not a phenotype and doesn't imply one
# 16:43:02 | Processing entity: 'bilateral retinitis pigmentosa'
# 16:43:02 |   Verifying if 'bilateral retinitis pigmentosa' is a direct phenotype via binary matching
# 16:43:02 |     LLM binary verification: 'bilateral retinitis pigmentosa' is a phenotype
# 16:43:02 |   'bilateral retinitis pigmentosa' is a direct phenotype
# 16:43:02 | Processing entity: 'night blindness'
# 16:43:02 |   Verifying if 'night blindness' is a direct phenotype via binary matching
# 16:43:02 |     Exact match found: 'night blindness' matches 'night blindness' (HP:0000662)
# 16:43:02 |   'night blindness' is a direct phenotype
# 16:43:02 | Processing entity: 'similar symptoms'
# 16:43:02 |   Verifying if 'similar symptoms' is a direct phenotype via binary matching
# 16:43:03 |     LLM binary verification: 'similar symptoms' is not a phenotype
# 16:43:03 |   Checking if 'similar symptoms' implies a phenotype
# 16:43:04 |     LLM binary verification: 'similar symptoms' does not imply a phenotype
# 16:43:04 |   'similar symptoms' is not a phenotype and doesn't imply one
# 16:43:04 | Processing entity: 'polydactyly of both hands'
# 16:43:04 |   Verifying if 'polydactyly of both hands' is a direct phenotype via binary matching
# 16:43:05 |     LLM binary verification: 'polydactyly of both hands' is a phenotype
# 16:43:05 |   'polydactyly of both hands' is a direct phenotype
# 16:43:05 | Processing entity: 'six digits on each hand'
# 16:43:05 |   Verifying if 'six digits on each hand' is a direct phenotype via binary matching
# 16:43:05 |     LLM binary verification: 'six digits on each hand' is a phenotype
# 16:43:05 |   'six digits on each hand' is a direct phenotype
# 16:43:05 | Processing entity: 'Renal function is abnormal'
# 16:43:05 |   Verifying if 'Renal function is abnormal' is a direct phenotype via binary matching
# 16:43:06 |     LLM binary verification: 'Renal function is abnormal' is a phenotype
# 16:43:06 |   'Renal function is abnormal' is a direct phenotype
# 16:43:06 | Processing entity: 'elevated creatinine'
# 16:43:06 |   Verifying if 'elevated creatinine' is a direct phenotype via binary matching
# 16:43:06 |     Exact match found: 'elevated creatinine' matches 'elevated creatinine' (HP:0003259)
# 16:43:06 |   'elevated creatinine' is a direct phenotype
# Identified 7 phenotypes (direct or implied)
# Verified 7 phenotypes.
# Phenotype: vision loss
# Status: direct_phenotype
# ---
# Phenotype: bilateral retinitis pigmentosa
# Status: direct_phenotype
# ---
# Phenotype: night blindness
# Status: direct_phenotype
# ---
# Phenotype: polydactyly of both hands
# Status: direct_phenotype
# ---
# Phenotype: six digits on each hand
# Status: direct_phenotype
# ---
# Phenotype: Renal function is abnormal
# Status: direct_phenotype
# ---
# Phenotype: elevated creatinine
# Status: direct_phenotype
# ---
#
# Step 3: Matching phenotypes to HPO codes...
# Matching 7 phenotypes to HPO terms
# Successfully matched 7 phenotypes
# Matched 7 phenotypes to HPO codes.
# Entity: vision loss
# Context: 42-year-old female with progressive vision loss.
# Type: direct_phenotype
# Code: HP:0000572
# ---
# Entity: bilateral retinitis pigmentosa
# Context: bilateral retinitis pigmentosa.
# Type: direct_phenotype
# Code: HP:0000510
# ---
# Entity: night blindness
# Context: Patient reports night blindness since adolescence.
# Type: direct_phenotype
# Code: HP:0000662
# ---
# Entity: polydactyly of both hands
# Context: Physical exam also reveals polydactyly of both hands with six digits on each hand.
# Type: direct_phenotype
# Code: HP:0001161
# ---
# Entity: six digits on each hand
# Context: Physical exam also reveals polydactyly of both hands with six digits on each hand.
# Type: direct_phenotype
# Code: HP:0010442
# ---
# Entity: Renal function is abnormal
# Context: Renal function is abnormal with elevated creatinine of 2.
# Type: direct_phenotype
# Code: HP:0012211
# ---
# Entity: elevated creatinine
# Context: Renal function is abnormal with elevated creatinine of 2.
# Type: direct_phenotype
# Code: HP:0003259
# ---
#
#
# ================================================================================
# PIPELINE SUMMARY
# ================================================================================
# Total extracted entities: 19
# Total verified phenotypes: 16
# Total matched HPO codes: 16
# Direct phenotypes: 15
# Implied phenotypes: 1
